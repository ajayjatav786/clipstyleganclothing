# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/mfrashad/ClothingGAN/blob/master/ClothingGAN_Demo.ipynb)
# # Clothing GAN demo
# Notebook by [@mfrashad](https://mfrashad.com)
#
#
# <br>
# Make sure runtime type is GPU

# %%
#@title Install dependencies (restart runtime after installing)
# # from IPython.display import Javascript
# display(Javascript('''google.colab.output.setIframeHeight(0, true, {maxHeight: 200})'''))
# !pip3 install ninja gradio fbpca boto3 requests==2.23.0 urllib3==1.25.11
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: ninja in /home/ai/.local/lib/python3.8/site-packages (1.11.1)
# Requirement already satisfied: gradio in /home/ai/.local/lib/python3.8/site-packages (3.24.1)
# Requirement already satisfied: fbpca in /home/ai/.local/lib/python3.8/site-packages (1.0)
# Requirement already satisfied: boto3 in /home/ai/.local/lib/python3.8/site-packages (1.26.108)
# Requirement already satisfied: requests==2.23.0 in /home/ai/.local/lib/python3.8/site-packages (2.23.0)
# /usr/share/python-wheels/urllib3-1.25.8-py2.py3-none-any.whl/urllib3/connectionpool.py:999: InsecureRequestWarning: Unverified HTTPS request is being made to host 'pypi.ngc.nvidia.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
# Collecting urllib3==1.25.11
#   Downloading urllib3-1.25.11-py2.py3-none-any.whl (127 kB)
#      |████████████████████████████████| 127 kB 5.1 MB/s eta 0:00:01
# Requirement already satisfied: pydantic in /home/ai/.local/lib/python3.8/site-packages (from gradio) (1.10.4)
# Requirement already satisfied: mdit-py-plugins<=0.3.3 in /home/ai/.local/lib/python3.8/site-packages (from gradio) (0.3.3)
# Requirement already satisfied: pandas in /home/ai/.local/lib/python3.8/site-packages (from gradio) (1.5.3)
# Requirement already satisfied: fastapi in /home/ai/.local/lib/python3.8/site-packages (from gradio) (0.88.0)
# Requirement already satisfied: jinja2 in /home/ai/.local/lib/python3.8/site-packages (from gradio) (3.1.2)
# Requirement already satisfied: httpx in /home/ai/.local/lib/python3.8/site-packages (from gradio) (0.23.3)
# Requirement already satisfied: markupsafe in /home/ai/.local/lib/python3.8/site-packages (from gradio) (2.1.1)
# Requirement already satisfied: matplotlib in /home/ai/.local/lib/python3.8/site-packages (from gradio) (3.6.3)
# Requirement already satisfied: orjson in /home/ai/.local/lib/python3.8/site-packages (from gradio) (3.8.9)
# Requirement already satisfied: pyyaml in /home/ai/.local/lib/python3.8/site-packages (from gradio) (5.4.1)
# Requirement already satisfied: pillow in /home/ai/.local/lib/python3.8/site-packages (from gradio) (9.5.0)
# Requirement already satisfied: ffmpy in /home/ai/.local/lib/python3.8/site-packages (from gradio) (0.3.0)
# Requirement already satisfied: numpy in /home/ai/.local/lib/python3.8/site-packages (from gradio) (1.24.1)
# Requirement already satisfied: aiohttp in /home/ai/.local/lib/python3.8/site-packages (from gradio) (3.8.3)
# Requirement already satisfied: gradio-client>=0.0.5 in /home/ai/.local/lib/python3.8/site-packages (from gradio) (0.0.8)
# Requirement already satisfied: websockets>=10.0 in /home/ai/.local/lib/python3.8/site-packages (from gradio) (10.4)
# Requirement already satisfied: typing-extensions in /home/ai/.local/lib/python3.8/site-packages (from gradio) (4.4.0)
# Requirement already satisfied: uvicorn in /home/ai/.local/lib/python3.8/site-packages (from gradio) (0.20.0)
# Requirement already satisfied: altair>=4.2.0 in /home/ai/.local/lib/python3.8/site-packages (from gradio) (4.2.2)
# Requirement already satisfied: huggingface-hub>=0.13.0 in /home/ai/.local/lib/python3.8/site-packages (from gradio) (0.13.4)
# Requirement already satisfied: semantic-version in /home/ai/.local/lib/python3.8/site-packages (from gradio) (2.10.0)
# Requirement already satisfied: python-multipart in /home/ai/.local/lib/python3.8/site-packages (from gradio) (0.0.6)
# Requirement already satisfied: markdown-it-py[linkify]>=2.0.0 in /home/ai/.local/lib/python3.8/site-packages (from gradio) (2.2.0)
# Requirement already satisfied: pydub in /home/ai/.local/lib/python3.8/site-packages (from gradio) (0.25.1)
# Requirement already satisfied: aiofiles in /home/ai/.local/lib/python3.8/site-packages (from gradio) (23.1.0)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/ai/.local/lib/python3.8/site-packages (from boto3) (1.0.1)
# Requirement already satisfied: s3transfer<0.7.0,>=0.6.0 in /home/ai/.local/lib/python3.8/site-packages (from boto3) (0.6.0)
# Requirement already satisfied: botocore<1.30.0,>=1.29.108 in /home/ai/.local/lib/python3.8/site-packages (from boto3) (1.29.108)
# Requirement already satisfied: idna<3,>=2.5 in /home/ai/.local/lib/python3.8/site-packages (from requests==2.23.0) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ai/.local/lib/python3.8/site-packages (from requests==2.23.0) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/lib/python3/dist-packages (from requests==2.23.0) (3.0.4)
# Requirement already satisfied: pytz>=2020.1 in /home/ai/.local/lib/python3.8/site-packages (from pandas->gradio) (2022.7)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/ai/.local/lib/python3.8/site-packages (from pandas->gradio) (2.8.2)
# Requirement already satisfied: starlette==0.22.0 in /home/ai/.local/lib/python3.8/site-packages (from fastapi->gradio) (0.22.0)
# Requirement already satisfied: sniffio in /home/ai/.local/lib/python3.8/site-packages (from httpx->gradio) (1.3.0)
# Requirement already satisfied: httpcore<0.17.0,>=0.15.0 in /home/ai/.local/lib/python3.8/site-packages (from httpx->gradio) (0.16.3)
# Requirement already satisfied: rfc3986[idna2008]<2,>=1.3 in /home/ai/.local/lib/python3.8/site-packages (from httpx->gradio) (1.5.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/ai/.local/lib/python3.8/site-packages (from matplotlib->gradio) (1.4.4)
# Requirement already satisfied: contourpy>=1.0.1 in /home/ai/.local/lib/python3.8/site-packages (from matplotlib->gradio) (1.0.7)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/ai/.local/lib/python3.8/site-packages (from matplotlib->gradio) (2.4.7)
# Requirement already satisfied: fonttools>=4.22.0 in /home/ai/.local/lib/python3.8/site-packages (from matplotlib->gradio) (4.38.0)
# Requirement already satisfied: cycler>=0.10 in /home/ai/.local/lib/python3.8/site-packages (from matplotlib->gradio) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in /home/ai/.local/lib/python3.8/site-packages (from matplotlib->gradio) (22.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/ai/.local/lib/python3.8/site-packages (from aiohttp->gradio) (1.8.2)
# Requirement already satisfied: attrs>=17.3.0 in /home/ai/.local/lib/python3.8/site-packages (from aiohttp->gradio) (22.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/ai/.local/lib/python3.8/site-packages (from aiohttp->gradio) (1.3.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/ai/.local/lib/python3.8/site-packages (from aiohttp->gradio) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /home/ai/.local/lib/python3.8/site-packages (from aiohttp->gradio) (4.0.2)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /home/ai/.local/lib/python3.8/site-packages (from aiohttp->gradio) (2.0.7)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/ai/.local/lib/python3.8/site-packages (from aiohttp->gradio) (1.3.1)
# Requirement already satisfied: fsspec in /home/ai/.local/lib/python3.8/site-packages (from gradio-client>=0.0.5->gradio) (2022.11.0)
# Requirement already satisfied: click>=7.0 in /home/ai/.local/lib/python3.8/site-packages (from uvicorn->gradio) (8.1.3)
# Requirement already satisfied: h11>=0.8 in /home/ai/.local/lib/python3.8/site-packages (from uvicorn->gradio) (0.14.0)
# Requirement already satisfied: toolz in /home/ai/.local/lib/python3.8/site-packages (from altair>=4.2.0->gradio) (0.12.0)
# Requirement already satisfied: entrypoints in /usr/lib/python3/dist-packages (from altair>=4.2.0->gradio) (0.3)
# Requirement already satisfied: jsonschema>=3.0 in /usr/lib/python3/dist-packages (from altair>=4.2.0->gradio) (3.2.0)
# Requirement already satisfied: filelock in /home/ai/.local/lib/python3.8/site-packages (from huggingface-hub>=0.13.0->gradio) (3.9.0)
# Requirement already satisfied: tqdm>=4.42.1 in /home/ai/.local/lib/python3.8/site-packages (from huggingface-hub>=0.13.0->gradio) (4.64.1)
# Requirement already satisfied: mdurl~=0.1 in /home/ai/.local/lib/python3.8/site-packages (from markdown-it-py[linkify]>=2.0.0->gradio) (0.1.2)
# Requirement already satisfied: linkify-it-py<3,>=1; extra == "linkify" in /home/ai/.local/lib/python3.8/site-packages (from markdown-it-py[linkify]>=2.0.0->gradio) (2.0.0)
# Requirement already satisfied: six>=1.5 in /home/ai/.local/lib/python3.8/site-packages (from python-dateutil>=2.8.1->pandas->gradio) (1.16.0)
# Requirement already satisfied: anyio<5,>=3.4.0 in /home/ai/.local/lib/python3.8/site-packages (from starlette==0.22.0->fastapi->gradio) (3.6.2)
# Requirement already satisfied: uc-micro-py in /home/ai/.local/lib/python3.8/site-packages (from linkify-it-py<3,>=1; extra == "linkify"->markdown-it-py[linkify]>=2.0.0->gradio) (1.0.1)
# ERROR: selenium 4.8.0 has requirement urllib3[socks]~=1.26, but you'll have urllib3 1.25.11 which is incompatible.
# ERROR: banana-dev 4.0.1 has requirement requests<3.0.0,>=2.26.0, but you'll have requests 2.23.0 which is incompatible.
# ERROR: awscli 1.27.108 has requirement rsa<4.8,>=3.1.2, but you'll have rsa 4.9 which is incompatible.
# ERROR: apify-client 0.6.0 has requirement requests~=2.28.0, but you'll have requests 2.23.0 which is incompatible.
# Installing collected packages: urllib3
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.26.15
#     Uninstalling urllib3-1.26.15:
#       Successfully uninstalled urllib3-1.26.15
# Successfully installed urllib3-1.25.11

# %%
# !git clone https://github.com/mfrashad/ClothingGAN.git
# %cd ClothingGAN/

# %%
# #@title Install other dependencies
# from IPython.display import Javascript
# display(Javascript('''google.colab.output.setIframeHeight(0, true, {maxHeight: 200})'''))
# !git submodule update --init --recursive
# !python -c "import nltk; nltk.download('wordnet')"

# %%
# !pip3 install urllib3==1.25.11
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: urllib3==1.25.11 in /home/ai/.local/lib/python3.8/site-packages (1.25.11)

# %%
# !pip3 install awscli --ignore-installed six
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# /usr/share/python-wheels/urllib3-1.25.8-py2.py3-none-any.whl/urllib3/connectionpool.py:999: InsecureRequestWarning: Unverified HTTPS request is being made to host 'pypi.ngc.nvidia.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
# Collecting awscli
#   Downloading awscli-1.27.108-py3-none-any.whl (4.0 MB)
#      |████████████████████████████████| 4.0 MB 6.8 MB/s eta 0:00:01
# /usr/share/python-wheels/urllib3-1.25.8-py2.py3-none-any.whl/urllib3/connectionpool.py:999: InsecureRequestWarning: Unverified HTTPS request is being made to host 'pypi.ngc.nvidia.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
# Collecting six
#   Downloading six-1.16.0-py2.py3-none-any.whl (11 kB)
# /usr/share/python-wheels/urllib3-1.25.8-py2.py3-none-any.whl/urllib3/connectionpool.py:999: InsecureRequestWarning: Unverified HTTPS request is being made to host 'pypi.ngc.nvidia.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
# Collecting s3transfer<0.7.0,>=0.6.0
#   Downloading s3transfer-0.6.0-py3-none-any.whl (79 kB)
#      |████████████████████████████████| 79 kB 7.2 MB/s eta 0:00:011
# /usr/share/python-wheels/urllib3-1.25.8-py2.py3-none-any.whl/urllib3/connectionpool.py:999: InsecureRequestWarning: Unverified HTTPS request is being made to host 'pypi.ngc.nvidia.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
# Collecting botocore==1.29.108
#   Downloading botocore-1.29.108-py3-none-any.whl (10.6 MB)
#      |████████████████████████████████| 10.6 MB 4.2 MB/s eta 0:00:01
# /usr/share/python-wheels/urllib3-1.25.8-py2.py3-none-any.whl/urllib3/connectionpool.py:999: InsecureRequestWarning: Unverified HTTPS request is being made to host 'pypi.ngc.nvidia.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
# Collecting docutils<0.17,>=0.10
#   Downloading docutils-0.16-py2.py3-none-any.whl (548 kB)
#      |████████████████████████████████| 548 kB 8.8 MB/s eta 0:00:01
# /usr/share/python-wheels/urllib3-1.25.8-py2.py3-none-any.whl/urllib3/connectionpool.py:999: InsecureRequestWarning: Unverified HTTPS request is being made to host 'pypi.ngc.nvidia.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
# Collecting rsa<4.8,>=3.1.2
#   Downloading rsa-4.7.2-py3-none-any.whl (34 kB)
# /usr/share/python-wheels/urllib3-1.25.8-py2.py3-none-any.whl/urllib3/connectionpool.py:999: InsecureRequestWarning: Unverified HTTPS request is being made to host 'pypi.ngc.nvidia.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
# Collecting colorama<0.4.5,>=0.2.5
#   Downloading colorama-0.4.4-py2.py3-none-any.whl (16 kB)
# /usr/share/python-wheels/urllib3-1.25.8-py2.py3-none-any.whl/urllib3/connectionpool.py:999: InsecureRequestWarning: Unverified HTTPS request is being made to host 'pypi.ngc.nvidia.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
# Collecting PyYAML<5.5,>=3.10
#   Downloading PyYAML-5.4.1-cp38-cp38-manylinux1_x86_64.whl (662 kB)
#      |████████████████████████████████| 662 kB 9.7 MB/s eta 0:00:01
# /usr/share/python-wheels/urllib3-1.25.8-py2.py3-none-any.whl/urllib3/connectionpool.py:999: InsecureRequestWarning: Unverified HTTPS request is being made to host 'pypi.ngc.nvidia.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
# Collecting urllib3<1.27,>=1.25.4
#   Downloading urllib3-1.26.15-py2.py3-none-any.whl (140 kB)
#      |████████████████████████████████| 140 kB 6.7 MB/s eta 0:00:01
# /usr/share/python-wheels/urllib3-1.25.8-py2.py3-none-any.whl/urllib3/connectionpool.py:999: InsecureRequestWarning: Unverified HTTPS request is being made to host 'pypi.ngc.nvidia.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
# Collecting jmespath<2.0.0,>=0.7.1
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# /usr/share/python-wheels/urllib3-1.25.8-py2.py3-none-any.whl/urllib3/connectionpool.py:999: InsecureRequestWarning: Unverified HTTPS request is being made to host 'pypi.ngc.nvidia.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
# Collecting python-dateutil<3.0.0,>=2.1
#   Downloading python_dateutil-2.8.2-py2.py3-none-any.whl (247 kB)
#      |████████████████████████████████| 247 kB 5.7 MB/s eta 0:00:01
# /usr/share/python-wheels/urllib3-1.25.8-py2.py3-none-any.whl/urllib3/connectionpool.py:999: InsecureRequestWarning: Unverified HTTPS request is being made to host 'pypi.ngc.nvidia.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
# Collecting pyasn1>=0.1.3
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
#      |████████████████████████████████| 77 kB 6.6 MB/s eta 0:00:01
# ERROR: launchpadlib 1.10.13 requires testresources, which is not installed.
# ERROR: requests 2.23.0 has requirement urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1, but you'll have urllib3 1.26.15 which is incompatible.
# ERROR: pandas-gbq 0.19.1 has requirement google-auth-oauthlib>=0.7.0, but you'll have google-auth-oauthlib 0.4.6 which is incompatible.
# ERROR: banana-dev 4.0.1 has requirement requests<3.0.0,>=2.26.0, but you'll have requests 2.23.0 which is incompatible.
# ERROR: apify-client 0.6.0 has requirement requests~=2.28.0, but you'll have requests 2.23.0 which is incompatible.
# Installing collected packages: urllib3, jmespath, six, python-dateutil, botocore, s3transfer, docutils, pyasn1, rsa, colorama, PyYAML, awscli
# Successfully installed PyYAML-5.4.1 awscli-1.27.108 botocore-1.29.108 colorama-0.4.4 docutils-0.16 jmespath-1.0.1 pyasn1-0.4.8 python-dateutil-2.8.2 rsa-4.9 s3transfer-0.6.0 six-1.16.0 urllib3-1.26.15

# %%
# !pip3 install imageio
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: imageio in /home/ai/.local/lib/python3.8/site-packages (2.27.0)
# Requirement already satisfied: numpy in /home/ai/.local/lib/python3.8/site-packages (from imageio) (1.24.1)
# Requirement already satisfied: pillow>=8.3.2 in /home/ai/.local/lib/python3.8/site-packages (from imageio) (9.5.0)

# %%
# !pip install ninja gradio
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: ninja in /home/ai/.local/lib/python3.8/site-packages (1.11.1)
# Requirement already satisfied: gradio in /home/ai/.local/lib/python3.8/site-packages (3.24.1)
# Requirement already satisfied: pydantic in /home/ai/.local/lib/python3.8/site-packages (from gradio) (1.10.4)
# Requirement already satisfied: numpy in /home/ai/.local/lib/python3.8/site-packages (from gradio) (1.24.1)
# Requirement already satisfied: orjson in /home/ai/.local/lib/python3.8/site-packages (from gradio) (3.8.9)
# Requirement already satisfied: huggingface-hub>=0.13.0 in /home/ai/.local/lib/python3.8/site-packages (from gradio) (0.13.4)
# Requirement already satisfied: uvicorn in /home/ai/.local/lib/python3.8/site-packages (from gradio) (0.20.0)
# Requirement already satisfied: aiohttp in /home/ai/.local/lib/python3.8/site-packages (from gradio) (3.8.3)
# Requirement already satisfied: websockets>=10.0 in /home/ai/.local/lib/python3.8/site-packages (from gradio) (10.4)
# Requirement already satisfied: requests in /home/ai/.local/lib/python3.8/site-packages (from gradio) (2.23.0)
# Requirement already satisfied: altair>=4.2.0 in /home/ai/.local/lib/python3.8/site-packages (from gradio) (4.2.2)
# Requirement already satisfied: fastapi in /home/ai/.local/lib/python3.8/site-packages (from gradio) (0.88.0)
# Requirement already satisfied: httpx in /home/ai/.local/lib/python3.8/site-packages (from gradio) (0.23.3)
# Requirement already satisfied: ffmpy in /home/ai/.local/lib/python3.8/site-packages (from gradio) (0.3.0)
# Requirement already satisfied: semantic-version in /home/ai/.local/lib/python3.8/site-packages (from gradio) (2.10.0)
# Requirement already satisfied: gradio-client>=0.0.5 in /home/ai/.local/lib/python3.8/site-packages (from gradio) (0.0.8)
# Requirement already satisfied: aiofiles in /home/ai/.local/lib/python3.8/site-packages (from gradio) (23.1.0)
# Requirement already satisfied: markupsafe in /home/ai/.local/lib/python3.8/site-packages (from gradio) (2.1.1)
# Requirement already satisfied: markdown-it-py[linkify]>=2.0.0 in /home/ai/.local/lib/python3.8/site-packages (from gradio) (2.2.0)
# Requirement already satisfied: pillow in /home/ai/.local/lib/python3.8/site-packages (from gradio) (9.5.0)
# Requirement already satisfied: jinja2 in /home/ai/.local/lib/python3.8/site-packages (from gradio) (3.1.2)
# Requirement already satisfied: pydub in /home/ai/.local/lib/python3.8/site-packages (from gradio) (0.25.1)
# Requirement already satisfied: typing-extensions in /home/ai/.local/lib/python3.8/site-packages (from gradio) (4.4.0)
# Requirement already satisfied: python-multipart in /home/ai/.local/lib/python3.8/site-packages (from gradio) (0.0.6)
# Requirement already satisfied: matplotlib in /home/ai/.local/lib/python3.8/site-packages (from gradio) (3.6.3)
# Requirement already satisfied: pyyaml in /home/ai/.local/lib/python3.8/site-packages (from gradio) (5.4.1)
# Requirement already satisfied: pandas in /home/ai/.local/lib/python3.8/site-packages (from gradio) (1.5.3)
# Requirement already satisfied: mdit-py-plugins<=0.3.3 in /home/ai/.local/lib/python3.8/site-packages (from gradio) (0.3.3)
# Requirement already satisfied: packaging>=20.9 in /home/ai/.local/lib/python3.8/site-packages (from huggingface-hub>=0.13.0->gradio) (22.0)
# Requirement already satisfied: filelock in /home/ai/.local/lib/python3.8/site-packages (from huggingface-hub>=0.13.0->gradio) (3.9.0)
# Requirement already satisfied: tqdm>=4.42.1 in /home/ai/.local/lib/python3.8/site-packages (from huggingface-hub>=0.13.0->gradio) (4.64.1)
# Requirement already satisfied: h11>=0.8 in /home/ai/.local/lib/python3.8/site-packages (from uvicorn->gradio) (0.14.0)
# Requirement already satisfied: click>=7.0 in /home/ai/.local/lib/python3.8/site-packages (from uvicorn->gradio) (8.1.3)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /home/ai/.local/lib/python3.8/site-packages (from aiohttp->gradio) (2.0.7)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /home/ai/.local/lib/python3.8/site-packages (from aiohttp->gradio) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/ai/.local/lib/python3.8/site-packages (from aiohttp->gradio) (1.8.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/ai/.local/lib/python3.8/site-packages (from aiohttp->gradio) (6.0.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/ai/.local/lib/python3.8/site-packages (from aiohttp->gradio) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /home/ai/.local/lib/python3.8/site-packages (from aiohttp->gradio) (22.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/ai/.local/lib/python3.8/site-packages (from aiohttp->gradio) (1.3.3)
# Requirement already satisfied: idna<3,>=2.5 in /home/ai/.local/lib/python3.8/site-packages (from requests->gradio) (2.10)
# /usr/share/python-wheels/urllib3-1.25.8-py2.py3-none-any.whl/urllib3/connectionpool.py:999: InsecureRequestWarning: Unverified HTTPS request is being made to host 'pypi.ngc.nvidia.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
# Collecting urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1
#   Downloading urllib3-1.25.11-py2.py3-none-any.whl (127 kB)
#      |████████████████████████████████| 127 kB 2.6 MB/s eta 0:00:01
# Requirement already satisfied: certifi>=2017.4.17 in /home/ai/.local/lib/python3.8/site-packages (from requests->gradio) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/lib/python3/dist-packages (from requests->gradio) (3.0.4)
# Requirement already satisfied: toolz in /home/ai/.local/lib/python3.8/site-packages (from altair>=4.2.0->gradio) (0.12.0)
# Requirement already satisfied: jsonschema>=3.0 in /usr/lib/python3/dist-packages (from altair>=4.2.0->gradio) (3.2.0)
# Requirement already satisfied: entrypoints in /usr/lib/python3/dist-packages (from altair>=4.2.0->gradio) (0.3)
# Requirement already satisfied: starlette==0.22.0 in /home/ai/.local/lib/python3.8/site-packages (from fastapi->gradio) (0.22.0)
# Requirement already satisfied: sniffio in /home/ai/.local/lib/python3.8/site-packages (from httpx->gradio) (1.3.0)
# Requirement already satisfied: rfc3986[idna2008]<2,>=1.3 in /home/ai/.local/lib/python3.8/site-packages (from httpx->gradio) (1.5.0)
# Requirement already satisfied: httpcore<0.17.0,>=0.15.0 in /home/ai/.local/lib/python3.8/site-packages (from httpx->gradio) (0.16.3)
# Requirement already satisfied: fsspec in /home/ai/.local/lib/python3.8/site-packages (from gradio-client>=0.0.5->gradio) (2022.11.0)
# Requirement already satisfied: mdurl~=0.1 in /home/ai/.local/lib/python3.8/site-packages (from markdown-it-py[linkify]>=2.0.0->gradio) (0.1.2)
# Requirement already satisfied: linkify-it-py<3,>=1; extra == "linkify" in /home/ai/.local/lib/python3.8/site-packages (from markdown-it-py[linkify]>=2.0.0->gradio) (2.0.0)
# Requirement already satisfied: cycler>=0.10 in /home/ai/.local/lib/python3.8/site-packages (from matplotlib->gradio) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/ai/.local/lib/python3.8/site-packages (from matplotlib->gradio) (1.0.7)
# Requirement already satisfied: python-dateutil>=2.7 in /home/ai/.local/lib/python3.8/site-packages (from matplotlib->gradio) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /home/ai/.local/lib/python3.8/site-packages (from matplotlib->gradio) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/ai/.local/lib/python3.8/site-packages (from matplotlib->gradio) (1.4.4)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/ai/.local/lib/python3.8/site-packages (from matplotlib->gradio) (2.4.7)
# Requirement already satisfied: pytz>=2020.1 in /home/ai/.local/lib/python3.8/site-packages (from pandas->gradio) (2022.7)
# Requirement already satisfied: anyio<5,>=3.4.0 in /home/ai/.local/lib/python3.8/site-packages (from starlette==0.22.0->fastapi->gradio) (3.6.2)
# Requirement already satisfied: uc-micro-py in /home/ai/.local/lib/python3.8/site-packages (from linkify-it-py<3,>=1; extra == "linkify"->markdown-it-py[linkify]>=2.0.0->gradio) (1.0.1)
# Requirement already satisfied: six>=1.5 in /home/ai/.local/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib->gradio) (1.16.0)
# ERROR: selenium 4.8.0 has requirement urllib3[socks]~=1.26, but you'll have urllib3 1.25.11 which is incompatible.
# ERROR: banana-dev 4.0.1 has requirement requests<3.0.0,>=2.26.0, but you'll have requests 2.23.0 which is incompatible.
# ERROR: awscli 1.27.108 has requirement rsa<4.8,>=3.1.2, but you'll have rsa 4.9 which is incompatible.
# ERROR: apify-client 0.6.0 has requirement requests~=2.28.0, but you'll have requests 2.23.0 which is incompatible.
# Installing collected packages: urllib3
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.26.15
#     Uninstalling urllib3-1.26.15:
#       Successfully uninstalled urllib3-1.26.15
# Successfully installed urllib3-1.25.11

# %%
# !ls
# Out:
# cache			    flagged			__pycache__
# ClothingGAN_Demo.ipynb	    interactive.py		README.md
# clothing-gan.gif	    LICENSE			SETUP.md
# clothing-gan-thumbnail.gif  lookbook-001800.pt		stylegan2-ada-pytorch
# config.py		    lookbook-interpolation.gif	stylegan2-pytorch
# decomposition.py	    models			teaser.jpg
# deps			    mtest.py			tests
# dnnlib			    netdissect			TkTorchWindow.py
# environment.yml		    notebooks			torch_utils
# estimators.py		    out				utils.py
# ffhq.pkl		    pretrained			visualize.py

# %%
#@title Load Model
selected_model = 'lookbook'

# Load model
from IPython.utils import io
import torch
import PIL
import numpy as np
import ipywidgets as widgets
from PIL import Image
import imageio
from models import get_instrumented_model
from decomposition import get_or_compute
from config import Config
from skimage import img_as_ubyte

# Speed up computation
torch.autograd.set_grad_enabled(False)
torch.backends.cudnn.benchmark = True

# Specify model to use
config = Config(
  model='StyleGAN2',
  layer='style',
  output_class=selected_model,
  components=80,
  use_w=True,
  batch_size=5_000, # style layer quite small
)

inst = get_instrumented_model(config.model, config.output_class,
                              config.layer, torch.device('cuda'), use_w=config.use_w)

# print(inst,"---------inst----------")


path_to_components = get_or_compute(config, inst)

print(path_to_components,"---------path_to_components----------")

model = inst.model

comps = np.load(path_to_components)
lst = comps.files
latent_dirs = []
latent_stdevs = []

load_activations = False

for item in lst:
    if load_activations:
      if item == 'act_comp':
        for i in range(comps[item].shape[0]):
          latent_dirs.append(comps[item][i])
      if item == 'act_stdev':
        for i in range(comps[item].shape[0]):
          latent_stdevs.append(comps[item][i])
    else:
      if item == 'lat_comp':
        for i in range(comps[item].shape[0]):
          latent_dirs.append(comps[item][i])
      if item == 'lat_stdev':
        for i in range(comps[item].shape[0]):
          latent_stdevs.append(comps[item][i])
# Out:
# /home/ai/Videos/ClothingGAN/cache/components/stylegan2-lookbook_style_ipca_c80_n300000_w.npz ---------path_to_components----------

# %%
lst
# Out:
# ['act_comp',
#  'act_mean',
#  'act_stdev',
#  'lat_comp',
#  'lat_mean',
#  'lat_stdev',
#  'var_ratio',
#  'random_stdevs']

# %%
print(latent_dirs)
# Out:
# [array([[ 3.39387693e-02, -1.58484224e-02, -1.89207420e-02,
#          1.85156744e-02,  1.23892836e-02, -1.16252173e-02,
#         -1.85972452e-02,  2.99013723e-02, -2.87246169e-03,
#          1.49151357e-02, -2.48783850e-03,  1.41691621e-02,
#         -3.32979560e-02,  2.18339022e-02,  7.80477421e-03,
#         -1.39413625e-02,  1.76648272e-03,  1.98597945e-02,
#          8.32141191e-02, -8.11836272e-02, -4.28656563e-02,
#          1.26654673e-02,  4.45088707e-02]], dtype=float32)]

# %%
print(latent_stdevs)
# Out:
# [5.067111, 4.3010054, 3.891467, 3.369765, 2.7237296, 2.37989, 1.9702119, 1.6218915, 1.5717387, 1.4263443, 1.2334745, 1.0241781, 0.9841895, 0.926933, 0.8757503, 0.84876, 0.855123, 0.8033804, 0.7774795, 0.7767346, 0.7567814, 0.7402133, 0.7209568, 0.7198498, 0.70373493, 0.6748262, 0.66645646, 0.6597117, 0.6662135, 0.63146245, 0.6230061, 0.60557973, 0.60855085, 0.5872668, 0.58429474, 0.57515377, 0.55776954, 0.5622266, 0.55262685, 0.5595965, 0.54376405, 0.5330173, 0.5336015, 0.5313615, 0.5078277, 0.5001003, 0.50859433, 0.4975807, 0.49583945, 0.47624525, 0.48252487, 0.4694545, 0.46550697, 0.46914372, 0.47105283, 0.45738232, 0.44656816, 0.44983965, 0.4473314, 0.43797776, 0.4349918, 0.4164378, 0.42079005, 0.4173249, 0.40929675, 0.41115072, 0.3979782, 0.3985921, 0.39331433, 0.3927233, 0.38699216, 0.38274178, 0.3830442, 0.37479755, 0.378084, 0.36963868, 0.36421484, 0.3709891, 0.36807662, 0.36204267]

# %%
#@title Define functions
from ipywidgets import fixed

# Taken from https://github.com/alexanderkuk/log-progress
def log_progress(sequence, every=1, size=None, name='Items'):
    from ipywidgets import IntProgress, HTML, VBox
    from IPython.display import display

    is_iterator = False
    if size is None:
        try:
            size = len(sequence)
        except TypeError:
            is_iterator = True
    if size is not None:
        if every is None:
            if size <= 200:
                every = 1
            else:
                every = int(size / 200)     # every 0.5%
    else:
        assert every is not None, 'sequence is iterator, set every'

    if is_iterator:
        progress = IntProgress(min=0, max=1, value=1)
        progress.bar_style = 'info'
    else:
        progress = IntProgress(min=0, max=size, value=0)
    label = HTML()
    box = VBox(children=[label, progress])
    display(box)

    index = 0
    try:
        for index, record in enumerate(sequence, 1):
            if index == 1 or index % every == 0:
                if is_iterator:
                    label.value = '{name}: {index} / ?'.format(
                        name=name,
                        index=index
                    )
                else:
                    progress.value = index
                    label.value = u'{name}: {index} / {size}'.format(
                        name=name,
                        index=index,
                        size=size
                    )
            yield record
    except:
        progress.bar_style = 'danger'
        raise
    else:
        progress.bar_style = 'success'
        progress.value = index
        label.value = "{name}: {index}".format(
            name=name,
            index=str(index or '?')
        )

def name_direction(sender):
  if not text.value:
    print('Please name the direction before saving')
    return
    
  if num in named_directions.values():
    target_key = list(named_directions.keys())[list(named_directions.values()).index(num)]
    print(f'Direction already named: {target_key}')
    print(f'Overwriting... ')
    del(named_directions[target_key])
  named_directions[text.value] = [num, start_layer.value, end_layer.value]
  save_direction(random_dir, text.value)
  for item in named_directions:
    print(item, named_directions[item])

def save_direction(direction, filename):
  filename += ".npy"
  np.save(filename, direction, allow_pickle=True, fix_imports=True)
  print(f'Latent direction saved as {filename}')

def mix_w(w1, w2, content, style):
    for i in range(0,5):
        w2[i] = w1[i] * (1 - content) + w2[i] * content

    for i in range(5, 16):
        w2[i] = w1[i] * (1 - style) + w2[i] * style
    
    return w2

def display_sample_pytorch(seed, truncation, directions, distances, scale, start, end, w=None, disp=True, save=None, noise_spec=None):
    # blockPrint()
    print(truncation,"--------------tttt")
    model.truncation = truncation
    if w is None:
        w = model.sample_latent(1, seed=seed).detach().cpu().numpy()
        w = [w]*model.get_max_latents() # one per layer
    else:
        w = [np.expand_dims(x, 0) for x in w]
    
    for l in range(start, end):
      for i in range(len(directions)):
        w[l] = w[l] + directions[i] * distances[i] * scale
    
    torch.cuda.empty_cache()
    #save image and display
    out = model.sample_np(w)
    final_im = Image.fromarray((out * 255).astype(np.uint8)).resize((500,500),Image.LANCZOS)
    
    
    if save is not None:
      if disp == False:
        print(save)
      final_im.save(f'out/{seed}_{save:05}.png')
    if disp:
      display(final_im)
    
    return final_im

def generate_mov(seed, truncation, direction_vec, scale, layers, n_frames, out_name = 'out', noise_spec = None, loop=True):
  """Generates a mov moving back and forth along the chosen direction vector"""
  # Example of reading a generated set of images, and storing as MP4.
  # %mkdir out
  movieName = f'out/{out_name}.mp4'
  offset = -10
  step = 20 / n_frames
  imgs = []
  for i in log_progress(range(n_frames), name = "Generating frames"):
    print(f'\r{i} / {n_frames}', end='')
    w = model.sample_latent(1, seed=seed).cpu().numpy()

    model.truncation = truncation
    w = [w]*model.get_max_latents() # one per layer
    for l in layers:
      if l <= model.get_max_latents():
          w[l] = w[l] + direction_vec * offset * scale

    #save image and display
    out = model.sample_np(w)
    final_im = Image.fromarray((out * 255).astype(np.uint8))
    imgs.append(out)
    #increase offset
    offset += step
  if loop:
    imgs += imgs[::-1]
  with imageio.get_writer(movieName, mode='I') as writer:
    for image in log_progress(list(imgs), name = "Creating animation"):
        writer.append_data(img_as_ubyte(image))

# %%
import numpy as np

def generate_image(seed1, seed2, content, style, truncation, c0, c1, c2, c3, c4, c5, c6, start_layer, end_layer):
    seed1 = int(seed1)
    seed2 = int(seed2)

    scale = 1
    params = {'c0': c0,
          'c1': c1,
          'c2': c2,
          'c3': c3,
          'c4': c4,
          'c5': c5,
          'c6': c6}

    param_indexes = {'c0': 0,
              'c1': 1,
              'c2': 2,
              'c3': 3,
              'c4': 4,
              'c5': 5,
              'c6': 6}

    directions = []
    distances = []
    for k, v in params.items():
        directions.append(latent_dirs[param_indexes[k]])
        distances.append(v)
        
#     print(directions)
    w1 = model.sample_latent(1, seed=seed1).detach().cpu().numpy()
    w1 = [w1]*model.get_max_latents() # one per layer
    im1 = model.sample_np(w1)

    w2 = model.sample_latent(1, seed=seed2).detach().cpu().numpy()
    w2 = [w2]*model.get_max_latents() # one per layer
    im2 = model.sample_np(w2)
    combined_im = np.concatenate([im1, im2], axis=1)
    input_im = Image.fromarray((combined_im * 255).astype(np.uint8))
    

    mixed_w = mix_w(w1, w2, content, style)
    print(input_im)

    

    return input_im
# Out:
# <PIL.Image.Image image mode=RGB size=1024x512 at 0x7F1D3D4C7970>
# <PIL.Image.Image image mode=RGB size=1024x512>
# 0.9 --------------tttt
# (<PIL.Image.Image image mode=RGB size=1024x512>,
#  <PIL.Image.Image image mode=RGB size=500x500>)
# 0 -----------------c0
# 0 -----------------c1
# 0.5 --------------tttt
# 0 -----------------c0
# 0 -----------------c1
# 0.5 --------------tttt
# 0 -----------------c0
# 0 -----------------c1
# 0.5 --------------tttt

# %%
truncation = 0.9
start_layer = 0
end_layer = 14
seed1 = 0
seed2 = 0
content = 0.9
style = 0.2

slider_max_val = 20
slider_min_val = -20
slider_step = 1

c0 = 0
c1 = 0
c2 = 0
c3 = 0
c4 = 0
c5 = 0
c6 = 0

scale = 1

# %%
input_im=generate_image(seed1, seed2, content, style, truncation, c0, c1, c2, c3, c4, c5, c6, start_layer, end_layer)

display(input_im)

# %%
#@title Demo UI
import gradio as gr
import numpy as np

def generate_image(seed1, seed2, content, style, truncation, c0, c1, c2, c3, c4, c5, c6, start_layer, end_layer):
    print(c0,"-----------------c0")
    print(c1,"-----------------c1")

    seed1 = int(seed1)
    seed2 = int(seed2)

    scale = 1
    params = {'c0': c0,
          'c1': c1,
          'c2': c2,
          'c3': c3,
          'c4': c4,
          'c5': c5,
          'c6': c6}

    param_indexes = {'c0': 0,
              'c1': 1,
              'c2': 2,
              'c3': 3,
              'c4': 4,
              'c5': 5,
              'c6': 6}

    directions = []
    distances = []
    for k, v in params.items():
        directions.append(latent_dirs[param_indexes[k]])
        distances.append(v)

    w1 = model.sample_latent(1, seed=seed1).detach().cpu().numpy()
    w1 = [w1]*model.get_max_latents() # one per layer
    im1 = model.sample_np(w1)

    w2 = model.sample_latent(1, seed=seed2).detach().cpu().numpy()
    w2 = [w2]*model.get_max_latents() # one per layer
    im2 = model.sample_np(w2)
    combined_im = np.concatenate([im1, im2], axis=1)
    input_im = Image.fromarray((combined_im * 255).astype(np.uint8))
    

    mixed_w = mix_w(w1, w2, content, style)
    return input_im, display_sample_pytorch(seed1, truncation, directions, distances, scale, int(start_layer), int(end_layer), w=mixed_w, disp=False)

truncation = gr.inputs.Slider(minimum=0, maximum=1, default=0.5, label="Truncation")
start_layer = gr.inputs.Number(default=0, label="Start Layer")
end_layer = gr.inputs.Number(default=14, label="End Layer")
seed1 = gr.inputs.Number(default=0, label="Seed 1")
seed2 = gr.inputs.Number(default=0, label="Seed 2")
content = gr.inputs.Slider(label="Structure", minimum=0, maximum=1, default=0.5)
style = gr.inputs.Slider(label="Style", minimum=0, maximum=1, default=0.5)

slider_max_val = 20
slider_min_val = -20
slider_step = 1

c0 = gr.inputs.Slider(label="Sleeve & Size", minimum=slider_min_val, maximum=slider_max_val, default=0)
c1 = gr.inputs.Slider(label="Dress - Jacket", minimum=slider_min_val, maximum=slider_max_val, default=0)
c2 = gr.inputs.Slider(label="Female Coat", minimum=slider_min_val, maximum=slider_max_val, default=0)
c3 = gr.inputs.Slider(label="Coat", minimum=slider_min_val, maximum=slider_max_val, default=0)
c4 = gr.inputs.Slider(label="Graphics", minimum=slider_min_val, maximum=slider_max_val, default=0)
c5 = gr.inputs.Slider(label="Dark", minimum=slider_min_val, maximum=slider_max_val, default=0)
c6 = gr.inputs.Slider(label="Less Cleavage", minimum=slider_min_val, maximum=slider_max_val, default=0)

print(c0,"----",c1)
scale = 1

inputs = [seed1, seed2, content, style, truncation, c0, c1, c2, c3, c4, c5, c6, start_layer, end_layer]
print(inputs)

gr.Interface(generate_image, inputs, ["image", "image"], live=True, title="ClothingGAN").launch()
# Out:
# /home/ai/.local/lib/python3.8/site-packages/gradio/inputs.py:89: UserWarning: Usage of gradio.inputs is deprecated, and will not be supported in the future, please import your component from gradio.components
#   warnings.warn(
# /home/ai/.local/lib/python3.8/site-packages/gradio/deprecation.py:40: UserWarning: `optional` parameter is deprecated, and it has no effect
#   warnings.warn(value)
# /home/ai/.local/lib/python3.8/site-packages/gradio/inputs.py:59: UserWarning: Usage of gradio.inputs is deprecated, and will not be supported in the future, please import your component from gradio.components
#   warnings.warn(
# slider ---- slider
# [number, number, slider, slider, slider, slider, slider, slider, slider, slider, slider, slider, number, number]
# /home/ai/.local/lib/python3.8/site-packages/gradio/blocks.py:254: UserWarning: api_name predict already exists, using predict_1
#   warnings.warn(
# /home/ai/.local/lib/python3.8/site-packages/gradio/blocks.py:254: UserWarning: api_name predict already exists, using predict_2
#   warnings.warn(
# /home/ai/.local/lib/python3.8/site-packages/gradio/blocks.py:254: UserWarning: api_name predict already exists, using predict_3
#   warnings.warn(
# /home/ai/.local/lib/python3.8/site-packages/gradio/blocks.py:254: UserWarning: api_name predict already exists, using predict_4
#   warnings.warn(
# /home/ai/.local/lib/python3.8/site-packages/gradio/blocks.py:254: UserWarning: api_name predict already exists, using predict_5
#   warnings.warn(
# /home/ai/.local/lib/python3.8/site-packages/gradio/blocks.py:254: UserWarning: api_name predict already exists, using predict_6
#   warnings.warn(
# /home/ai/.local/lib/python3.8/site-packages/gradio/blocks.py:254: UserWarning: api_name predict already exists, using predict_7
#   warnings.warn(
# /home/ai/.local/lib/python3.8/site-packages/gradio/blocks.py:254: UserWarning: api_name predict already exists, using predict_8
#   warnings.warn(
# /home/ai/.local/lib/python3.8/site-packages/gradio/blocks.py:254: UserWarning: api_name predict already exists, using predict_9
#   warnings.warn(
# /home/ai/.local/lib/python3.8/site-packages/gradio/blocks.py:254: UserWarning: api_name predict already exists, using predict_10
#   warnings.warn(
# /home/ai/.local/lib/python3.8/site-packages/gradio/blocks.py:254: UserWarning: api_name predict already exists, using predict_11
#   warnings.warn(
# /home/ai/.local/lib/python3.8/site-packages/gradio/blocks.py:254: UserWarning: api_name predict already exists, using predict_12
#   warnings.warn(
# /home/ai/.local/lib/python3.8/site-packages/gradio/blocks.py:254: UserWarning: api_name predict already exists, using predict_13
#   warnings.warn(
# Running on local URL:  http://127.0.0.1:7868
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7868/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# 0 -----------------c0
# 0 -----------------c1
# 0.5 --------------tttt
# 0 -----------------c0
# 0 -----------------c1
# 0.5 --------------tttt
# 0 -----------------c0
# 0 -----------------c1
# 0.5 --------------tttt
