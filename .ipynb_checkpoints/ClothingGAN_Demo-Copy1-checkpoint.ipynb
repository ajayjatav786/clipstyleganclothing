# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/mfrashad/ClothingGAN/blob/master/ClothingGAN_Demo.ipynb)
# # Clothing GAN demo
# Notebook by [@mfrashad](https://mfrashad.com)
#
#
# <br>
# Make sure runtime type is GPU

# %%
# @title Install dependencies (restart runtime after installing)
# # from IPython.display import Javascript
# display(Javascript('''google.colab.output.setIframeHeight(0, true, {maxHeight: 200})'''))
# !pip3 install ninja gradio fbpca boto3 requests==2.23.0 urllib3==1.25.11
# Out:
# Collecting ninja
#   Using cached ninja-1.11.1-py2.py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (145 kB)
# Collecting gradio
#   Downloading gradio-3.24.1-py3-none-any.whl (15.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.7/15.7 MB 7.0 MB/s eta 0:00:0000:0100:01
# Collecting fbpca
#   Downloading fbpca-1.0.tar.gz (11 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: boto3 in /home/aj/anaconda3/lib/python3.7/site-packages (1.26.64)
# Collecting requests==2.23.0
#   Downloading requests-2.23.0-py2.py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.4/58.4 kB 5.1 MB/s eta 0:00:00
# Collecting urllib3==1.25.11
#   Downloading urllib3-1.25.11-py2.py3-none-any.whl (127 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.0/128.0 kB 6.5 MB/s eta 0:00:00
# Requirement already satisfied: idna<3,>=2.5 in /home/aj/anaconda3/lib/python3.7/site-packages (from requests==2.23.0) (2.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /home/aj/anaconda3/lib/python3.7/site-packages (from requests==2.23.0) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/aj/anaconda3/lib/python3.7/site-packages (from requests==2.23.0) (2019.3.9)
# Requirement already satisfied: numpy in /home/aj/anaconda3/lib/python3.7/site-packages (from gradio) (1.21.6)
# Collecting ffmpy
#   Downloading ffmpy-0.3.0.tar.gz (4.8 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: fastapi in /home/aj/anaconda3/lib/python3.7/site-packages (from gradio) (0.90.0)
# Requirement already satisfied: aiohttp in /home/aj/anaconda3/lib/python3.7/site-packages (from gradio) (3.8.4)
# Collecting huggingface-hub>=0.13.0
#   Downloading huggingface_hub-0.13.4-py3-none-any.whl (200 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.1/200.1 kB 5.4 MB/s eta 0:00:00a 0:00:01
# Collecting mdit-py-plugins<=0.3.3
#   Downloading mdit_py_plugins-0.3.3-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.5/50.5 kB 7.9 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml in /home/aj/anaconda3/lib/python3.7/site-packages (from gradio) (5.1)
# Requirement already satisfied: markupsafe in /home/aj/anaconda3/lib/python3.7/site-packages (from gradio) (2.1.2)
# Requirement already satisfied: matplotlib in /home/aj/anaconda3/lib/python3.7/site-packages (from gradio) (3.5.3)
# Requirement already satisfied: pillow in /home/aj/anaconda3/lib/python3.7/site-packages (from gradio) (9.0.1)
# Requirement already satisfied: pandas in /home/aj/anaconda3/lib/python3.7/site-packages (from gradio) (1.3.5)
# Requirement already satisfied: jinja2 in /home/aj/anaconda3/lib/python3.7/site-packages (from gradio) (3.1.2)
# Requirement already satisfied: websockets>=10.0 in /home/aj/anaconda3/lib/python3.7/site-packages (from gradio) (10.4)
# Collecting orjson
#   Downloading orjson-3.8.10-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (271 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 271.4/271.4 kB 5.9 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: pydantic in /home/aj/anaconda3/lib/python3.7/site-packages (from gradio) (1.10.4)
# Requirement already satisfied: altair>=4.2.0 in /home/aj/anaconda3/lib/python3.7/site-packages (from gradio) (4.2.2)
# Collecting semantic-version
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Collecting markdown-it-py[linkify]>=2.0.0
#   Using cached markdown_it_py-2.2.0-py3-none-any.whl (84 kB)
# Requirement already satisfied: typing-extensions in /home/aj/anaconda3/lib/python3.7/site-packages (from gradio) (4.5.0)
# Collecting aiofiles
#   Using cached aiofiles-23.1.0-py3-none-any.whl (14 kB)
# Collecting httpx
#   Downloading httpx-0.23.3-py3-none-any.whl (71 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.5/71.5 kB 5.6 MB/s eta 0:00:00
# Collecting pydub
#   Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Collecting python-multipart
#   Downloading python_multipart-0.0.6-py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 kB 7.0 MB/s eta 0:00:00
# Collecting gradio-client>=0.0.5
#   Downloading gradio_client-0.0.8-py3-none-any.whl (20 kB)
# Requirement already satisfied: uvicorn in /home/aj/anaconda3/lib/python3.7/site-packages (from gradio) (0.20.0)
# Requirement already satisfied: botocore<1.30.0,>=1.29.64 in /home/aj/anaconda3/lib/python3.7/site-packages (from boto3) (1.29.64)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/aj/anaconda3/lib/python3.7/site-packages (from boto3) (1.0.1)
# Requirement already satisfied: s3transfer<0.7.0,>=0.6.0 in /home/aj/anaconda3/lib/python3.7/site-packages (from boto3) (0.6.0)
# Requirement already satisfied: jsonschema>=3.0 in /home/aj/anaconda3/lib/python3.7/site-packages (from altair>=4.2.0->gradio) (3.0.1)
# Requirement already satisfied: toolz in /home/aj/anaconda3/lib/python3.7/site-packages (from altair>=4.2.0->gradio) (0.9.0)
# Requirement already satisfied: entrypoints in /home/aj/anaconda3/lib/python3.7/site-packages (from altair>=4.2.0->gradio) (0.3)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/aj/anaconda3/lib/python3.7/site-packages (from botocore<1.30.0,>=1.29.64->boto3) (2.8.0)
# Requirement already satisfied: fsspec in /home/aj/anaconda3/lib/python3.7/site-packages (from gradio-client>=0.0.5->gradio) (2023.1.0)
# Requirement already satisfied: packaging in /home/aj/anaconda3/lib/python3.7/site-packages (from gradio-client>=0.0.5->gradio) (23.0)
# Requirement already satisfied: importlib-metadata in /home/aj/anaconda3/lib/python3.7/site-packages (from huggingface-hub>=0.13.0->gradio) (6.0.0)
# Requirement already satisfied: tqdm>=4.42.1 in /home/aj/anaconda3/lib/python3.7/site-packages (from huggingface-hub>=0.13.0->gradio) (4.59.0)
# Requirement already satisfied: filelock in /home/aj/anaconda3/lib/python3.7/site-packages (from huggingface-hub>=0.13.0->gradio) (3.0.10)
# Collecting mdurl~=0.1
#   Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Collecting linkify-it-py<3,>=1
#   Downloading linkify_it_py-2.0.0-py3-none-any.whl (19 kB)
# Requirement already satisfied: pytz>=2017.3 in /home/aj/anaconda3/lib/python3.7/site-packages (from pandas->gradio) (2018.9)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/aj/anaconda3/lib/python3.7/site-packages (from aiohttp->gradio) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /home/aj/anaconda3/lib/python3.7/site-packages (from aiohttp->gradio) (4.0.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/aj/anaconda3/lib/python3.7/site-packages (from aiohttp->gradio) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/aj/anaconda3/lib/python3.7/site-packages (from aiohttp->gradio) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /home/aj/anaconda3/lib/python3.7/site-packages (from aiohttp->gradio) (19.1.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/aj/anaconda3/lib/python3.7/site-packages (from aiohttp->gradio) (1.8.2)
# Requirement already satisfied: asynctest==0.13.0 in /home/aj/anaconda3/lib/python3.7/site-packages (from aiohttp->gradio) (0.13.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /home/aj/anaconda3/lib/python3.7/site-packages (from aiohttp->gradio) (3.0.1)
# Requirement already satisfied: starlette<=0.23.0,>=0.22.0 in /home/aj/anaconda3/lib/python3.7/site-packages (from fastapi->gradio) (0.23.0)
# Collecting rfc3986[idna2008]<2,>=1.3
#   Downloading rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Collecting httpcore<0.17.0,>=0.15.0
#   Downloading httpcore-0.16.3-py3-none-any.whl (69 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.6/69.6 kB 2.5 MB/s eta 0:00:00
# Requirement already satisfied: sniffio in /home/aj/anaconda3/lib/python3.7/site-packages (from httpx->gradio) (1.3.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/aj/anaconda3/lib/python3.7/site-packages (from matplotlib->gradio) (4.38.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/aj/anaconda3/lib/python3.7/site-packages (from matplotlib->gradio) (2.3.1)
# Requirement already satisfied: cycler>=0.10 in /home/aj/anaconda3/lib/python3.7/site-packages (from matplotlib->gradio) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/aj/anaconda3/lib/python3.7/site-packages (from matplotlib->gradio) (1.0.1)
# Requirement already satisfied: h11>=0.8 in /home/aj/anaconda3/lib/python3.7/site-packages (from uvicorn->gradio) (0.14.0)
# Requirement already satisfied: click>=7.0 in /home/aj/anaconda3/lib/python3.7/site-packages (from uvicorn->gradio) (8.1.3)
# Requirement already satisfied: six in /home/aj/anaconda3/lib/python3.7/site-packages (from cycler>=0.10->matplotlib->gradio) (1.15.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in /home/aj/anaconda3/lib/python3.7/site-packages (from httpcore<0.17.0,>=0.15.0->httpx->gradio) (3.6.2)
# Requirement already satisfied: pyrsistent>=0.14.0 in /home/aj/anaconda3/lib/python3.7/site-packages (from jsonschema>=3.0->altair>=4.2.0->gradio) (0.14.11)
# Requirement already satisfied: setuptools in /home/aj/anaconda3/lib/python3.7/site-packages (from jsonschema>=3.0->altair>=4.2.0->gradio) (67.1.0)
# Collecting uc-micro-py
#   Downloading uc_micro_py-1.0.1-py3-none-any.whl (6.2 kB)
# Requirement already satisfied: zipp>=0.5 in /home/aj/anaconda3/lib/python3.7/site-packages (from importlib-metadata->huggingface-hub>=0.13.0->gradio) (3.12.1)
# Building wheels for collected packages: fbpca, ffmpy
#   Building wheel for fbpca (setup.py) ... done
#   Created wheel for fbpca: filename=fbpca-1.0-py3-none-any.whl size=11373 sha256=fbbca3ce69b7fcec14a2c62474f6d6bbbbc317253cde40b30e3694fd3b10fae0
#   Stored in directory: /home/aj/.cache/pip/wheels/93/08/0c/1b9866c35c8d3f136d100dfe88036a32e0795437daca089f70
#   Building wheel for ffmpy (setup.py) ... done
#   Created wheel for ffmpy: filename=ffmpy-0.3.0-py3-none-any.whl size=4693 sha256=c9465cf05bb4469780db5dd14a7ef958db67d9ade49a65f1cf7a9dae30030660
#   Stored in directory: /home/aj/.cache/pip/wheels/13/e4/6c/e8059816e86796a597c6e6b0d4c880630f51a1fcfa0befd5e6
# Successfully built fbpca ffmpy
# Installing collected packages: rfc3986, pydub, ninja, ffmpy, fbpca, urllib3, uc-micro-py, semantic-version, python-multipart, orjson, mdurl, aiofiles, requests, markdown-it-py, linkify-it-py, httpcore, mdit-py-plugins, huggingface-hub, httpx, gradio-client, gradio
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.26.14
#     Uninstalling urllib3-1.26.14:
#       Successfully uninstalled urllib3-1.26.14
#   Attempting uninstall: requests
#     Found existing installation: requests 2.28.2
#     Uninstalling requests-2.28.2:
#       Successfully uninstalled requests-2.28.2
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.12.1
#     Uninstalling huggingface-hub-0.12.1:
#       Successfully uninstalled huggingface-hub-0.12.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# conda 22.9.0 requires ruamel_yaml_conda>=0.11.14, which is not installed.
# retinaface 1.1.1 requires tensorflow==2.5.0, but you have tensorflow 2.11.0 which is incompatible.
# nilearn 0.10.0 requires requests>=2.25.0, but you have requests 2.23.0 which is incompatible.
# datasets 2.9.0 requires tqdm>=4.62.1, but you have tqdm 4.59.0 which is incompatible.
# Successfully installed aiofiles-23.1.0 fbpca-1.0 ffmpy-0.3.0 gradio-3.24.1 gradio-client-0.0.8 httpcore-0.16.3 httpx-0.23.3 huggingface-hub-0.13.4 linkify-it-py-2.0.0 markdown-it-py-2.2.0 mdit-py-plugins-0.3.3 mdurl-0.1.2 ninja-1.11.1 orjson-3.8.10 pydub-0.25.1 python-multipart-0.0.6 requests-2.23.0 rfc3986-1.5.0 semantic-version-2.10.0 uc-micro-py-1.0.1 urllib3-1.25.11

# %%
# !git clone https://github.com/mfrashad/ClothingGAN.git
# %cd ClothingGAN/

# %%
# #@title Install other dependencies
# from IPython.display import Javascript
# display(Javascript('''google.colab.output.setIframeHeight(0, true, {maxHeight: 200})'''))
# !git submodule update --init --recursive
# !python -c "import nltk; nltk.download('wordnet')"
# Out:
# Submodule 'stylegan/stylegan_tf' (https://github.com/NVlabs/stylegan.git) registered for path '../../stylegan/stylegan_tf'
# Submodule 'stylegan2/stylegan2-pytorch' (https://github.com/harskish/stylegan2-pytorch.git) registered for path './'
# Cloning into '/media/aj/9c4728aa-3a45-44cf-ada0-079baa4684ac/home/webtunix/stylegan/ClothingGAN/models/stylegan/stylegan_tf'...
# Cloning into '/media/aj/9c4728aa-3a45-44cf-ada0-079baa4684ac/home/webtunix/stylegan/ClothingGAN/models/stylegan2/stylegan2-pytorch'...
# Submodule path '../../stylegan/stylegan_tf': checked out '66813a32aac5045fcde72751522a0c0ba963f6f2'
# Submodule path './': checked out '91ea2a7a4320701535466cce942c9e099d65670e'
# [nltk_data] Downloading package wordnet to /home/aj/nltk_data...

# %%
# !pip3 install urllib3==1.25.11

# %%
# !pip3 install awscli --ignore-installed six

# %%
# !pip3 install imageio

# %%
# !pip install ninja gradio

# %%
# !ls

# %%
#@title Load Model
selected_model = 'lookbook'

# Load model
from IPython.utils import io
import torch
import PIL
import numpy as np
import ipywidgets as widgets
from PIL import Image
import imageio
from models import get_instrumented_model
from decomposition import get_or_compute
from config import Config
from skimage import img_as_ubyte

# Speed up computation
torch.autograd.set_grad_enabled(False)
torch.backends.cudnn.benchmark = True

# Specify model to use
config = Config(
  model='StyleGAN2',
  layer='style',
  output_class=selected_model,
  components=80,
  use_w=True,
  batch_size=5_000, # style layer quite small
)

inst = get_instrumented_model(config.model, config.output_class,
                              config.layer, torch.device('cuda'), use_w=config.use_w)
model = inst.model

from matplotlib import pyplot as plt
w_l = model.sample_latent(1, seed=5).detach().cpu().numpy()
# Out:
# /home/aj/anaconda3/lib/python3.7/site-packages/torch/cuda/__init__.py:88: UserWarning: CUDA initialization: Unexpected error from cudaGetDeviceCount(). Did you run some cuda functions before calling NumCudaDevices() that might have already set an error? Error 804: forward compatibility was attempted on non supported HW (Triggered internally at ../c10/cuda/CUDAFunctions.cpp:109.)
#   return torch._C._cuda_getDeviceCount() > 0
# No CUDA runtime is found, using CUDA_HOME='/usr/local/cuda-11.4'
# StyleGAN2: Optimized CUDA op FusedLeakyReLU not available, using native PyTorch fallback.
# StyleGAN2: Optimized CUDA op UpFirDn2d not available, using native PyTorch fallback.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-18-fb7893538e5a> in <module>
#      30
#      31 inst = get_instrumented_model(config.model, config.output_class,
# ---> 32                               config.layer, torch.device('cuda'), use_w=config.use_w)
#      33 model = inst.model
#      34
#
# ~/anaconda3/lib/python3.7/functools.py in wrapper(*args, **kw)
#     825                             '1 positional argument')
#     826
# --> 827         return dispatch(args[0].__class__)(*args, **kw)
#     828
#     829     funcname = getattr(func, '__name__', 'singledispatch function')
#
# /media/aj/9c4728aa-3a45-44cf-ada0-079baa4684ac/home/webtunix/stylegan/ClothingGAN/models/wrappers.py in get_instrumented_model(name, output_class, layers, device, **kwargs)
#     695 @singledispatch
#     696 def get_instrumented_model(name, output_class, layers, device, **kwargs):
# --> 697     model = get_model(name, output_class, device, **kwargs)
#     698     model.eval()
#     699
#
# ~/anaconda3/lib/python3.7/functools.py in wrapper(*args, **kw)
#     825                             '1 positional argument')
#     826
# --> 827         return dispatch(args[0].__class__)(*args, **kw)
#     828
#     829     funcname = getattr(func, '__name__', 'singledispatch function')
#
# /media/aj/9c4728aa-3a45-44cf-ada0-079baa4684ac/home/webtunix/stylegan/ClothingGAN/models/wrappers.py in get_model(name, output_class, device, **kwargs)
#     680         model = StyleGAN(device, class_name=output_class)
#     681     elif name == 'StyleGAN2':
# --> 682         model = StyleGAN2(device, class_name=output_class)
#     683     else:
#     684         raise RuntimeError(f'Unknown model {name}')
#
# /media/aj/9c4728aa-3a45-44cf-ada0-079baa4684ac/home/webtunix/stylegan/ClothingGAN/models/wrappers.py in __init__(self, device, class_name, truncation, use_w)
#     124         self.name = f'StyleGAN2-{self.outclass}'
#     125         self.has_latent_residual = True
# --> 126         self.load_model()
#     127         self.set_noise_seed(0)
#     128
#
# /media/aj/9c4728aa-3a45-44cf-ada0-079baa4684ac/home/webtunix/stylegan/ClothingGAN/models/wrappers.py in load_model(self)
#     157         checkpoint = Path(checkpoint_root) / f'stylegan2/stylegan2_{self.outclass}_{self.resolution}.pt'
#     158
# --> 159         self.model = stylegan2.Generator(self.resolution, 512, 8).to(self.device)
#     160
#     161         if not checkpoint.is_file():
#
# ~/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py in to(self, *args, **kwargs)
#     987             return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None, non_blocking)
#     988
# --> 989         return self._apply(convert)
#     990
#     991     def register_backward_hook(
#
# ~/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py in _apply(self, fn)
#     639     def _apply(self, fn):
#     640         for module in self.children():
# --> 641             module._apply(fn)
#     642
#     643         def compute_should_use_set_data(tensor, tensor_applied):
#
# ~/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py in _apply(self, fn)
#     639     def _apply(self, fn):
#     640         for module in self.children():
# --> 641             module._apply(fn)
#     642
#     643         def compute_should_use_set_data(tensor, tensor_applied):
#
# ~/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py in _apply(self, fn)
#     662             # `with torch.no_grad():`
#     663             with torch.no_grad():
# --> 664                 param_applied = fn(param)
#     665             should_use_set_data = compute_should_use_set_data(param, param_applied)
#     666             if should_use_set_data:
#
# ~/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py in convert(t)
#     985                 return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None,
#     986                             non_blocking, memory_format=convert_to_format)
# --> 987             return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None, non_blocking)
#     988
#     989         return self._apply(convert)
#
# ~/anaconda3/lib/python3.7/site-packages/torch/cuda/__init__.py in _lazy_init()
#     227         if 'CUDA_MODULE_LOADING' not in os.environ:
#     228             os.environ['CUDA_MODULE_LOADING'] = 'LAZY'
# --> 229         torch._C._cuda_init()
#     230         # Some of the queued calls may reentrantly call _lazy_init();
#     231         # we need to just return without initializing in that case.
#
# RuntimeError: Unexpected error from cudaGetDeviceCount(). Did you run some cuda functions before calling NumCudaDevices() that might have already set an error? Error 804: forward compatibility was attempted on non supported HW

# %%
w_l.shape
# Out:
# (1, 512)

# %%
w1 = [w_l]*model.get_max_latents() # one per layer

# %%
import cv2
im1 = model.sample_np(w1)
im2 = model.sample_np(w_l)
com=np.hstack((im1,im2))
cv2.imwrite('new_i.png',com[:,:,::-1]*255)
plt.imshow(com)
plt.show()
